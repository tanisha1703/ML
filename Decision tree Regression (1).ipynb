# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set
import sklearn

# %%
df = pd.read_csv("longley.csv")

# %%
df.head(3)
# Out:
#        y    x1      x2    x3    x4      x5    x6
# 0  60323  83.0  234289  2356  1590  107608  1947
# 1  61122  88.5  259426  2325  1456  108632  1948
# 2  60171  88.2  258054  3682  1616  109773  1949

# %%
df = (df - df.mean())/df.std()

# %%
x = df.iloc[:,1:7]
y = df.iloc[:,0]

# %%
x.head(3)
# Out:
#          x1        x2        x3        x4        x5        x6
# 0 -1.731099 -1.543433 -0.896035 -1.460927 -1.411135 -1.575315
# 1 -1.221441 -1.290533 -0.929209 -1.653478 -1.263926 -1.365273
# 2 -1.249241 -1.304336  0.522960 -1.423566 -1.099898 -1.155231

# %%
y.head(3)
# Out:
# 0   -1.421995
# 1   -1.194487
# 2   -1.465275
# Name: y, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33, random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (10, 6) (6, 6) (10,) (6,)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model2 = DecisionTreeRegressor()

# %%
model2.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.tree import plot_tree
plot_tree(model2)
plt.show()

# %%
y_pred=model2.predict(x_test)
y_pred
# Out:
# array([-1.17597871, -1.17597871, -0.09339492,  1.49033233,  1.49033233,
#         1.49033233])

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("mse=",mean_squared_error(y_test,y_pred))
print("r2_value",r2_score(y_test,y_pred))
# Out:
# mse= 0.2883812959280116
# r2_value 0.7352270444451414

# %%
print("Important features are:")
importances=(model2.feature_importances_)
for i,v in enumerate(importances):
    print('Feature:%0d, Score: %0.4f' %(i,v))
# Out:
# Important features are:
# Feature:0, Score: 0.0031
# Feature:1, Score: 0.0000
# Feature:2, Score: 0.0687
# Feature:3, Score: 0.1411
# Feature:4, Score: 0.0014
# Feature:5, Score: 0.7857
